# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns
#import plotly.graph_objs as go


kill= pd.read_csv("/homes/alk30/DA_Project/Data/PoliceKillingsUS.csv", encoding='latin-1')
kill['age'].fillna((kill['age'].mean()), inplace=True)
kill['armed'].fillna('gun',inplace=True)
kill.dropna(subset=['race'],how='all', inplace = True)
kill.drop('flee',axis=1,inplace=True)
kill['name'].replace(['TK TK'],'Unknown',inplace = True)
kill_miss_values = kill.isnull().sum()
kill_miss_values[kill_miss_values >0 ]
# Out:
# Series([], dtype: int64)

# %%
kill.name.value_counts()
# Out:
# Unknown                         5
# Daquan Antonio Westbrook        2
# Michael Brown                   2
# Eric Harris                     2
# Brandon Jones                   2
# Michael Johnson                 2
# Jesus Juarez                    1
# Barry Jones                     1
# Quinton Phillips                1
# Travis Vierra                   1
# Walden Dang                     1
# Robert Becker                   1
# James Ellis                     1
# Alberto Hernandez               1
# Eugene McSwain                  1
# Trayvon Scruggs                 1
# La'vante Trevon Biggs           1
# Cesar Garcia                    1
# Darren Myron Fude               1
# Nathan Banks                    1
# Raymond Peralta-Lantigua        1
# Jeremy McDole                   1
# Kevin Thomas Snyder             1
# Thurman Reynolds                1
# Micah Dsheigh Jester            1
# David Brian Evans               1
# David Todd Powell               1
# Terrozza Tyree Griffin          1
# Darin Hutchins                  1
# Keith Richardson                1
#                                ..
# Kenneth Lanphier                1
# Roger Braswell                  1
# Daniel Davis                    1
# Richard Xavier Summers          1
# Brandon Wiley                   1
# Sylville Smith                  1
# Dionisio Augustine Garza III    1
# Jeff Martelli                   1
# Ralph Aguilar                   1
# Kent Norman                     1
# David Mack                      1
# Dennis Claude Stanley           1
# Anthony Hill                    1
# Alton Folmar                    1
# Russell Elswick                 1
# Marvin Cremeans                 1
# David Schwalm                   1
# Peter Gaines                    1
# Ron Harlan Lewallen             1
# Mya Hall                        1
# Marcus Wheeler                  1
# Patrick Earl Gatson             1
# Erick Emmanuel Sanchez          1
# Christie Cathers                1
# Autumn Steele                   1
# Bodhi Wilson Dean Phelps        1
# Levi Gene Wilson                1
# Danny Rendon                    1
# Bruce Steward                   1
# Kimber Key                      1
# Name: name, Length: 2331, dtype: int64

# %%
grouped_kill=kill.groupby('name')
for name,group in grouped_kill:
    print (name)
    print (group)
# Out:
#  Austin Wilburly  Reid
#       id                    name      date manner_of_death armed   age gender  \
# 689  820   Austin Wilburly  Reid  10/09/15            shot   gun  32.0      M
#
#     race  city state  signs_of_mental_illness threat_level  body_camera
# 689    W  Lodi    CA                    False       attack        False
# A'Donte Washington
#       id                name      date manner_of_death armed   age gender  \
# 136  176  A'Donte Washington  23/02/15            shot   gun  16.0      M
#
#     race       city state  signs_of_mental_illness threat_level  body_camera
# 136    B  Millbrook    AL                    False       attack        False
# Aaron Bailey
#         id          name      date manner_of_death    armed   age gender race  \
# 2440  2717  Aaron Bailey  29/06/17            shot  unarmed  45.0      M    B
#
#               city state  signs_of_mental_illness threat_level  body_camera
# 2440  Indianapolis    IN                    False        other        False
# Aaron M. Thompson
#         id               name      date manner_of_death  armed       age  \
# 2341  2600  Aaron M. Thompson  22/05/17            shot  knife  36.60537
#
#      gender race           city state  signs_of_mental_illness threat_level  \
# 2341      M    W  Mountain Home    ID                    False       attack
#
#       body_camera
# 2341        False
# Aaron Marchese
#       id            name      date manner_of_death       armed   age gender  \
# 588  713  Aaron Marchese  07/08/15            shot  toy weapon  30.0      M
#
#     race    city state  signs_of_mental_illness threat_level  body_camera
# 588    W  Fresno    CA                     True       attack        False
# Aaron Marquis Ballard
#         id                   name      date manner_of_death armed   age  \
# 1778  1989  Aaron Marquis Ballard  24/10/16            shot   gun  19.0
#
#      gender race             city state  signs_of_mental_illness threat_level  \
# 1778      M    B  North St. Louis    MO                    False       attack
#
#       body_camera
# 1778        False
# Aaron Rutledge
#       id            name      date manner_of_death armed   age gender race  \
# 250  303  Aaron Rutledge  02/04/15            shot   gun  27.0      M    W
#
#           city state  signs_of_mental_illness threat_level  body_camera
# 250  Pineville    LA                     True       attack        False
# Aaron Siler
#       id         name      date manner_of_death armed   age gender race  \
# 193  209  Aaron Siler  14/03/15            shot   gun  26.0      M    W
#
#         city state  signs_of_mental_illness threat_level  body_camera
# 193  Kenosha    WI                    False       attack        False
# Aaron Valdez
#       id          name      date manner_of_death    armed   age gender race  \
# 182  796  Aaron Valdez  11/03/15            shot  vehicle  25.0      M    H
#
#             city state  signs_of_mental_illness threat_level  body_camera
# 182  Los Angeles    CA                    False        other        False
# Abdul Razak Ali Artan
#         id                   name      date manner_of_death  armed   age  \
# 1868  2083  Abdul Razak Ali Artan  28/11/16            shot  knife  18.0
#
#      gender race      city state  signs_of_mental_illness threat_level  \
# 1868      M    O  Columbus    OH                    False       attack
#
#       body_camera
# 1868        False
# Abel Correa
#       id         name      date manner_of_death         armed   age gender  \
# 587  712  Abel Correa  07/08/15            shot  sharp object  24.0      M
#
#     race       city state  signs_of_mental_illness threat_level  body_camera
# 587    H  Las Vegas    NV                     True        other         True
# Abraham Martinez
#         id              name      date manner_of_death armed   age gender  \
# 1215  1393  Abraham Martinez  20/03/16            shot   gun  62.0      M
#
#      race        city state  signs_of_mental_illness threat_level  body_camera
# 1215    H  Fort Wayne    IN                    False       attack        False
# Abraham Mitchell Fryer
#         id                    name      date manner_of_death    armed   age  \
# 1153  1324  Abraham Mitchell Fryer  26/02/16            shot  unarmed  35.0
#
#      gender race          city state  signs_of_mental_illness threat_level  \
# 1153      M    W  Rapid Valley    SD                    False       attack
#
#       body_camera
# 1153        False
# Abraham Ortiz
#         id           name      date manner_of_death         armed   age  \
# 1804  2015  Abraham Ortiz  04/11/16            shot  undetermined  26.0
#
#      gender race          city state  signs_of_mental_illness  threat_level  \
# 1804      M    H  Palm Springs    CA                    False  undetermined
#
#       body_camera
# 1804        False
# Abraham Smith
#         id           name      date manner_of_death  armed   age gender race  \
# 1510  1700  Abraham Smith  08/07/16            shot  knife  30.0      M    W
#
#         city state  signs_of_mental_illness threat_level  body_camera
# 1510  Tucson    AZ                     True        other        False
# Adalid Flores
#         id           name      date manner_of_death    armed   age gender  \
# 1844  2053  Adalid Flores  19/11/16            shot  vehicle  29.0      M
#
#      race     city state  signs_of_mental_illness threat_level  body_camera
# 1844    H  Anaheim    CA                    False       attack         True
# Adam Dujanovic
#       id            name      date manner_of_death       armed   age gender  \
# 489  609  Adam Dujanovic  07/07/15            shot  metal pole  33.0      M
#
#     race  city state  signs_of_mental_illness threat_level  body_camera
# 489    W  Mesa    AZ                    False        other        False
# Adam Jo Klimek
#         id            name      date manner_of_death  armed   age gender race  \
# 1566  1757  Adam Jo Klimek  02/08/16            shot  knife  31.0      M    W
#
#             city state  signs_of_mental_illness threat_level  body_camera
# 1566  Alexandria    MN                    False        other        False
# Adam Karjalainen
#         id              name      date manner_of_death       armed   age  \
# 1025  1176  Adam Karjalainen  16/01/16            shot  toy weapon  44.0
#
#      gender race       city state  signs_of_mental_illness threat_level  \
# 1025      M    W  Beaverton    OR                    False        other
#
#       body_camera
# 1025        False
# Adam Reinhart
#       id           name      date manner_of_death armed   age gender race  \
# 167  271  Adam Reinhart  07/03/15            shot   gun  29.0      M    W
#
#         city state  signs_of_mental_illness threat_level  body_camera
# 167  Phoenix    AZ                    False       attack        False
# Adam Schneider
#       id            name      date manner_of_death armed   age gender race  \
# 631  762  Adam Schneider  22/08/15            shot   gun  31.0      M    W
#
#          city state  signs_of_mental_illness threat_level  body_camera
# 631  Cohasset    MN                    False       attack        False
# Adam Smith
#         id        name      date manner_of_death    armed   age gender race  \
# 1508  1698  Adam Smith  07/07/16            shot  vehicle  33.0      M    W
#
#         city state  signs_of_mental_illness threat_level  body_camera
# 1508  Clovis    CA                    False        other        False
# Adrian Hernandez
#       id              name      date manner_of_death       armed   age gender  \
# 233  258  Adrian Hernandez  27/03/15            shot  toy weapon  23.0      M
#
#     race         city state  signs_of_mental_illness threat_level  body_camera
# 233    H  Bakersfield    CA                    False       attack        False
# Adrian Joseph Shaffer
#         id                   name      date manner_of_death armed   age  \
# 1673  1897  Adrian Joseph Shaffer  10/09/16            shot   gun  37.0
#
#      gender race     city state  signs_of_mental_illness threat_level  \
# 1673      M    W  Boulder    CO                    False       attack
#
#       body_camera
# 1673         True
# Adrian Maurice Hardeman
#         id                     name      date manner_of_death armed   age  \
# 2376  2638  Adrian Maurice Hardeman  05/06/17            shot   gun  37.0
#
#      gender race         city state  signs_of_mental_illness threat_level  \
# 2376      M    B  San Antonio    TX                    False        other
#
#       body_camera
# 2376        False
# Adrian Simental
#       id             name      date manner_of_death    armed   age gender  \
# 446  555  Adrian Simental  21/06/15            shot  unarmed  24.0      M
#
#     race   city state  signs_of_mental_illness threat_level  body_camera
# 446    H  Azusa    CA                     True        other        False
# Adrian Solis
#       id          name      date manner_of_death  armed   age gender race  \
# 230  250  Adrian Solis  26/03/15            shot  knife  35.0      M    H
#
#            city state  signs_of_mental_illness threat_level  body_camera
# 230  Wilmington    CA                     True        other        False
# Adriene Jamarr Ludd
#       id                 name      date manner_of_death armed   age gender  \
# 800  945  Adriene Jamarr Ludd  22/10/15            shot   gun  36.0      M
#
#     race        city state  signs_of_mental_illness threat_level  body_camera
# 800    B  Carmichael    CA                    False       attack        False
# Akiel Denkins
#         id           name      date manner_of_death armed   age gender race  \
# 1157  1327  Akiel Denkins  29/02/16            shot   gun  24.0      M    B
#
#          city state  signs_of_mental_illness threat_level  body_camera
# 1157  Raleigh    NC                    False       attack        False
# Alan  Bellew
#       id          name      date manner_of_death       armed   age gender  \
# 462  577  Alan  Bellew  28/06/15            shot  toy weapon  29.0      M
#
#     race      city state  signs_of_mental_illness threat_level  body_camera
# 462    W  Portland    OR                    False       attack        False
# Alan Huberth Franco-Armenta
#         id                         name      date manner_of_death armed   age  \
# 1005  1153  Alan Huberth Franco-Armenta  06/01/16            shot   gun  32.0
#
#      gender race       city state  signs_of_mental_illness threat_level  \
# 1005      M    H  Carrizozo    NM                     True       attack
#
#       body_camera
# 1005        False
# Alan James
#      id        name      date manner_of_death armed   age gender race  \
# 72  112  Alan James  29/01/15            shot   gun  31.0      M    W
#
#        city state  signs_of_mental_illness threat_level  body_camera
# 72  Wyoming    MI                     True       attack        False
# Alan Joseph Rushton
#       id                 name      date manner_of_death  armed   age gender  \
# 630  761  Alan Joseph Rushton  21/08/15            shot  knife  38.0      M
#
#     race         city state  signs_of_mental_illness threat_level  body_camera
# 630    W  Wake Forest    NC                    False        other        False
# Alan Lance Alverson
#      id                 name      date manner_of_death armed   age gender  \
# 68  345  Alan Lance Alverson  28/01/15            shot   gun  45.0      M
#
#    race    city state  signs_of_mental_illness threat_level  body_camera
# 68    W  Sunset    TX                    False       attack        False
# Alan Paul Bartley
#         id               name      date manner_of_death    armed   age gender  \
# 1011  1162  Alan Paul Bartley  11/01/16            shot  vehicle  56.0      M
#
#      race          city state  signs_of_mental_illness threat_level  \
# 1011    W  San Fernando    CA                    False       attack
#
#       body_camera
# 1011        False
# Albert Gagnier
#         id            name      date manner_of_death armed   age gender race  \
# 2345  2605  Albert Gagnier  23/05/17            shot   gun  74.0      M    W
#
#            city state  signs_of_mental_illness threat_level  body_camera
# 2345  Knoxville    TN                    False       attack        False
# Albert Hanson
#       id           name      date manner_of_death armed   age gender race  \
# 315  406  Albert Hanson  26/04/15            shot   gun  76.0      M    W
#
#              city state  signs_of_mental_illness threat_level  body_camera
# 315  Kings County    CA                    False       attack        False
# Albert Joseph Davis
#       id                 name      date   manner_of_death    armed   age  \
# 528  651  Albert Joseph Davis  17/07/15  shot and Tasered  unarmed  23.0
#
#     gender race     city state  signs_of_mental_illness threat_level  \
# 528      M    B  Orlando    FL                    False       attack
#
#      body_camera
# 528        False
# Albert Thompson
#         id             name      date manner_of_death       armed   age  \
# 1002  1149  Albert Thompson  05/01/16            shot  hand torch  28.0
#
#      gender race   city state  signs_of_mental_illness threat_level  \
# 1002      M    H  Ceres    CA                    False        other
#
#       body_camera
# 1002        False
# Alberto Hernandez
#       id               name      date manner_of_death       armed   age  \
# 741  873  Alberto Hernandez  28/09/15            shot  toy weapon  59.0
#
#     gender race        city state  signs_of_mental_illness threat_level  \
# 741      M    H  San Ysidro    CA                    False       attack
#
#      body_camera
# 741         True
# Alec Ouzounian
#       id            name      date manner_of_death         armed   age gender  \
# 353  450  Alec Ouzounian  12/05/15            shot  undetermined  40.0      M
#
#     race                    city state  signs_of_mental_illness threat_level  \
# 353    W  Rancho Santa Margarita    CA                     True        other
#
#      body_camera
# 353        False
# Alejandro Alvarado
#         id                name      date manner_of_death  armed       age  \
# 2528  2812  Alejandro Alvarado  27/07/17            shot  knife  36.60537
#
#      gender race        city state  signs_of_mental_illness threat_level  \
# 2528      M    H  Chowchilla    CA                    False       attack
#
#       body_camera
# 2528        False
# Alejandro Campos Fernandez
#       id                        name      date manner_of_death armed   age  \
# 412  518  Alejandro Campos Fernandez  06/06/15            shot   gun  45.0
#
#     gender race          city state  signs_of_mental_illness threat_level  \
# 412      M    H  Watsonsville    CA                    False       attack
#
#      body_camera
# 412        False
# Alejandro Lerma
#       id             name      date manner_of_death armed   age gender race  \
# 736  870  Alejandro Lerma  26/09/15            shot   gun  23.0      M    H
#
#           city state  signs_of_mental_illness threat_level  body_camera
# 736  Lovington    NM                    False       attack        False
# Alejandro Salazar
#       id               name      date manner_of_death armed       age gender  \
# 124  584  Alejandro Salazar  20/02/15            shot   gun  36.60537      M
#
#     race     city state  signs_of_mental_illness threat_level  body_camera
# 124    H  Houston    TX                    False       attack        False
# Alejandro Valencia Mendez
#         id                       name      date   manner_of_death armed   age  \
# 2156  2402  Alejandro Valencia Mendez  04/03/17  shot and Tasered  pipe  70.0
#
#      gender race         city state  signs_of_mental_illness threat_level  \
# 2156      M    H  Los Angeles    CA                    False        other
#
#       body_camera
# 2156        False
# Alex Buckner
#         id          name      date manner_of_death armed   age gender race  \
# 1142  1317  Alex Buckner  23/02/16            shot   gun  26.0      M    W
#
#          city state  signs_of_mental_illness threat_level  body_camera
# 1142  Phoenix    AZ                     True       attack        False
# Alex Christopher Davis
#         id                    name      date   manner_of_death          armed  \
# 2067  2308  Alex Christopher Davis  07/02/17  shot and Tasered  piece of wood
#
#        age gender race            city state  signs_of_mental_illness  \
# 2067  18.0      M    W  Jackson County    AL                    False
#
#      threat_level  body_camera
# 2067        other        False
# Alexander Bonds
#         id             name      date manner_of_death armed   age gender race  \
# 2461  2742  Alexander Bonds  05/07/17            shot   gun  34.0      M    B
#
#           city state  signs_of_mental_illness threat_level  body_camera
# 2461  New York    NY                    False       attack        False
# Alexander Chance Partain
#         id                      name      date manner_of_death         armed  \
# 1874  2090  Alexander Chance Partain  29/11/16            shot  undetermined
#
#        age gender race city state  signs_of_mental_illness threat_level  \
# 1874  31.0      M    W  Iva    SC                    False        other
#
#       body_camera
# 1874        False
# Alexander J. Schoessel
#         id                    name      date manner_of_death armed   age  \
# 2516  2801  Alexander J. Schoessel  25/07/17            shot    ax  23.0
#
#      gender race      city state  signs_of_mental_illness threat_level  \
# 2516      M    W  Richmond    VA                     True        other
#
#       body_camera
# 2516        False
# Alexander Meltz
#         id             name      date manner_of_death           armed   age  \
# 2175  2423  Alexander Meltz  14/03/17            shot  unknown weapon  18.0
#
#      gender race         city state  signs_of_mental_illness threat_level  \
# 2175      M    W  Westminster    CO                    False       attack
#
#       body_camera
# 2175        False
# Alexander Myers
#       id             name      date manner_of_death armed   age gender race  \
# 258  298  Alexander Myers  06/04/15            shot   gun  23.0      M    W
#
#              city state  signs_of_mental_illness threat_level  body_camera
# 258  Indianapolis    IN                     True       attack        False
# Alexander Phillip Long
#       id                    name      date   manner_of_death    armed   age  \
# 140  180  Alexander Phillip Long  26/02/15  shot and Tasered  unarmed  31.0
#
#     gender race         city state  signs_of_mental_illness threat_level  \
# 140      M    W  Terre Haute    IN                    False        other
#
#      body_camera
# 140        False
# Alexander Tirado Rivera
#       id                     name      date manner_of_death       armed   age  \
# 397  501  Alexander Tirado Rivera  30/05/15            shot  toy weapon  39.0
#
#     gender race       city state  signs_of_mental_illness threat_level  \
# 397      M    H  Nashville    TN                    False       attack
#
#      body_camera
# 397        False
# Alexia Christian
#       id              name      date manner_of_death armed   age gender race  \
# 324  421  Alexia Christian  29/04/15            shot   gun  25.0      F    B
#
#         city state  signs_of_mental_illness threat_level  body_camera
# 324  Atlanta    GA                    False       attack        False
# Alexio Allen
#         id          name      date manner_of_death armed   age gender race  \
# 1224  1403  Alexio Allen  23/03/16            shot   gun  30.0      M    B
#
#          city state  signs_of_mental_illness threat_level  body_camera
# 1224  Raleigh    TN                     True       attack        False
# Alexis George Mishtowt
#         id                    name      date manner_of_death armed   age  \
# 1489  1686  Alexis George Mishtowt  01/07/16            shot   gun  63.0
#
#      gender race     city state  signs_of_mental_illness threat_level  \
# 1489      M    W  Landrum    SC                    False       attack
#
#       body_camera
# 1489        False
# Alfonso Lopez
#         id           name      date manner_of_death         armed   age  \
# 1944  2171  Alfonso Lopez  27/12/16            shot  undetermined  41.0
#
#      gender race             city state  signs_of_mental_illness threat_level  \
# 1944      M    H  North Riverside    IL                    False       attack
#
#       body_camera
# 1944        False
# Alfontish Cockerham
#       id                 name      date manner_of_death armed   age gender  \
# 445  582  Alfontish Cockerham  20/06/15            shot   gun  23.0      M
#
#     race     city state  signs_of_mental_illness threat_level  body_camera
# 445    B  Chicago    IL                    False       attack        False
# Alfred Longoria
#         id             name      date manner_of_death       armed   age  \
# 1023  1172  Alfred Longoria  16/01/16            shot  toy weapon  34.0
#
#      gender race             city state  signs_of_mental_illness threat_level  \
# 1023      M    H  Hollywood Hills    CA                    False        other
#
#       body_camera
# 1023        False
# Alfred Olango
#         id           name      date manner_of_death    armed   age gender  \
# 1710  1918  Alfred Olango  27/09/16            shot  unarmed  38.0      M
#
#      race      city state  signs_of_mental_illness threat_level  body_camera
# 1710    B  El Cajon    CA                     True       attack         True
# Alfredo Rials-Torres
#       id                  name      date manner_of_death    armed   age  \
# 362  457  Alfredo Rials-Torres  19/05/15            shot  unarmed  54.0
#
#     gender race       city state  signs_of_mental_illness threat_level  \
# 362      M    H  Arlington    VA                    False       attack
#
#      body_camera
# 362        False
# Ali Eisa Abdalla Yahia
#         id                    name      date   manner_of_death armed   age  \
# 1108  1268  Ali Eisa Abdalla Yahia  13/02/16  shot and Tasered   gun  29.0
#
#      gender race       city state  signs_of_mental_illness threat_level  \
# 1108      M    B  Urbandale    IA                    False       attack
#
#       body_camera
# 1108         True
# Alice Brown
#       id         name      date manner_of_death    armed   age gender race  \
# 201  221  Alice Brown  17/03/15            shot  vehicle  24.0      F    W
#
#               city state  signs_of_mental_illness threat_level  body_camera
# 201  San Francisco    CA                     True        other        False
# Alijah Jackson
#         id            name      date manner_of_death  armed   age gender race  \
# 1101  1258  Alijah Jackson  11/02/16            shot  knife  35.0      M    W
#
#         city state  signs_of_mental_illness threat_level  body_camera
# 1101  Maiden    NC                     True        other        False
# Allen Matthew Baker
#       id                 name      date manner_of_death armed   age gender  \
# 614  742  Allen Matthew Baker  15/08/15            shot   gun  23.0      M
#
#     race       city state  signs_of_mental_illness threat_level  body_camera
# 614    B  Sunnyvale    CA                    False       attack        False
# Allen Pacheco
#        id           name      date manner_of_death armed   age gender race  \
# 908  1053  Allen Pacheco  02/12/15            shot   gun  32.0      M    H
#
#             city state  signs_of_mental_illness threat_level  body_camera
# 908  San Antonio    TX                    False        other        False
# Allen Quintez Swader
#       id                  name      date manner_of_death armed   age gender  \
# 819  965  Allen Quintez Swader  29/10/15            shot   gun  18.0      M
#
#     race       city state  signs_of_mental_illness threat_level  body_camera
# 819    W  Hohenwald    TN                    False       attack        False
# Alonzo E. Ashley
#         id              name      date manner_of_death armed   age gender  \
# 2089  2321  Alonzo E. Ashley  11/02/17            shot   gun  27.0      M
#
#      race         city state  signs_of_mental_illness threat_level  \
# 2089    B  Kansas City    MO                    False       attack
#
#       body_camera
# 2089        False
# Alteria Woods
#         id           name      date manner_of_death    armed   age gender  \
# 2192  2442  Alteria Woods  19/03/17            shot  unarmed  21.0      F
#
#      race     city state  signs_of_mental_illness threat_level  body_camera
# 2192    B  Gifford    FL                    False        other        False
# Alton Fitzgerald Witchard
#         id                       name      date manner_of_death armed   age  \
# 1336  1525  Alton Fitzgerald Witchard  07/05/16            shot   gun  37.0
#
#      gender race            city state  signs_of_mental_illness threat_level  \
# 1336      M    B  St. Petersburg    FL                    False       attack
#
#       body_camera
# 1336        False
# Alton Folmar
#         id          name      date manner_of_death armed   age gender race  \
# 2417  2681  Alton Folmar  19/06/17            shot   gun  28.0      M    W
#
#         city state  signs_of_mental_illness threat_level  body_camera
# 2417  Dallas    TX                    False        other        False
# Alton Sterling
#         id            name      date   manner_of_death         armed   age  \
# 1501  1680  Alton Sterling  05/07/16  shot and Tasered  undetermined  37.0
#
#      gender race         city state  signs_of_mental_illness  threat_level  \
# 1501      M    B  Baton Rouge    LA                    False  undetermined
#
#       body_camera
# 1501         True
# Alva Burnett Braziel
#         id                  name      date manner_of_death armed   age gender  \
# 1512  1702  Alva Burnett Braziel  10/07/16            shot   gun  38.0      M
#
#      race     city state  signs_of_mental_illness threat_level  body_camera
# 1512    B  Houston    TX                    False        other         True
# Alvin R. Sylversmythe
#         id                   name      date manner_of_death  armed   age  \
# 1539  1730  Alvin R. Sylversmythe  24/07/16            shot  knife  29.0
#
#      gender race    city state  signs_of_mental_illness threat_level  \
# 1539      M    N  Gallup    NM                     True        other
#
#       body_camera
# 1539        False
# Amado Lago
#       id        name      date manner_of_death    armed   age gender race  \
# 757  897  Amado Lago  07/10/15            shot  machete  46.0      M    H
#
#                 city state  signs_of_mental_illness threat_level  body_camera
# 757  West Palm Beach    FL                    False       attack        False
# Amanda Page Bivens
#         id                name      date manner_of_death armed   age gender  \
# 1557  1747  Amanda Page Bivens  29/07/16            shot   gun  40.0      F
#
#      race      city state  signs_of_mental_illness threat_level  body_camera
# 1557    W  Homewood    AL                    False       attack        False
# Amber Lewis
#         id         name      date manner_of_death       armed   age gender  \
# 1903  2123  Amber Lewis  11/12/16            shot  toy weapon  44.0      F
#
#      race           city state  signs_of_mental_illness threat_level  \
# 1903    W  Bullhead City    AZ                     True       attack
#
#       body_camera
# 1903        False
# Ambroshia Fagre
#         id             name      date manner_of_death    armed   age gender  \
# 2082  2325  Ambroshia Fagre  10/02/17            shot  unarmed  18.0      F
#
#      race        city state  signs_of_mental_illness threat_level  body_camera
# 2082    W  Vassalboro    ME                    False        other        False
# Amilcar Perez-Lopez
#       id                 name      date manner_of_death  armed   age gender  \
# 142  182  Amilcar Perez-Lopez  26/02/15            shot  knife  21.0      M
#
#     race           city state  signs_of_mental_illness threat_level  \
# 142    H  San Francisco    CA                    False        other
#
#      body_camera
# 142        False
# Amos Frerichs
#        id           name      date manner_of_death    armed   age gender race  \
# 954  1101  Amos Frerichs  18/12/15            shot  vehicle  32.0      M    W
#
#           city state  signs_of_mental_illness threat_level  body_camera
# 954  Knoxville    TN                    False       attack        False
# Amy Jean McCoy
#         id            name      date manner_of_death   armed   age gender  \
# 1194  1362  Amy Jean McCoy  13/03/16            shot  hammer  38.0      F
#
#      race       city state  signs_of_mental_illness threat_level  body_camera
# 1194    W  Vancouver    WA                    False       attack        False
# Andre Dontrell Williams
#       id                     name      date   manner_of_death  armed   age  \
# 542  667  Andre Dontrell Williams  22/07/15  shot and Tasered  knife  26.0
#
#     gender race           city state  signs_of_mental_illness threat_level  \
# 542      M    B  Oklahoma City    OK                    False        other
#
#      body_camera
# 542        False
# Andre Green
#       id         name      date manner_of_death    armed   age gender race  \
# 596  715  Andre Green  09/08/15            shot  vehicle  15.0      M    B
#
#              city state  signs_of_mental_illness threat_level  body_camera
# 596  Indianapolis    IN                    False       attack        False
# Andre Johnson
#         id           name      date manner_of_death armed   age gender race  \
# 1511  1701  Andre Johnson  09/07/16            shot   gun  40.0      M    B
#
#             city state  signs_of_mental_illness threat_level  body_camera
# 1511  Broken Bow    OK                    False       attack        False
# Andres Lara-Rodriguez
#       id                   name      date manner_of_death armed   age gender  \
# 106  146  Andres Lara-Rodriguez  13/02/15            shot   gun  21.0      M
#
#     race         city state  signs_of_mental_illness threat_level  body_camera
# 106    H  Kansas City    KS                    False       attack        False
# Andrew Anthony Williams
#       id                     name      date manner_of_death    armed   age  \
# 165  270  Andrew Anthony Williams  06/03/15            shot  vehicle  48.0
#
#     gender race         city state  signs_of_mental_illness threat_level  \
# 165      M    B  Putnam Hall    FL                    False        other
#
#      body_camera
# 165        False
# Andrew Blake
#        id          name      date manner_of_death armed   age gender race  \
# 850  1013  Andrew Blake  10/11/15            shot   gun  22.0      M    W
#
#        city state  signs_of_mental_illness threat_level  body_camera
# 850  Dillon    MT                    False       attack        False
# Andrew Byrd
#         id         name      date manner_of_death    armed   age gender race  \
# 2063  2300  Andrew Byrd  05/02/17            shot  vehicle  33.0      M    H
#
#         city state  signs_of_mental_illness threat_level  body_camera
# 2063  Pueblo    CO                    False        other         True
# Andrew Charles Shipley
#       id                    name      date manner_of_death armed   age gender  \
# 199  216  Andrew Charles Shipley  17/03/15            shot   gun  49.0      M
#
#     race     city state  signs_of_mental_illness threat_level  body_camera
# 199    W  Medford    OR                     True       attack        False
# Andrew Driver
#       id           name      date manner_of_death  armed   age gender race  \
# 188  289  Andrew Driver  13/03/15            shot  knife  36.0      M    W
#
#         city state  signs_of_mental_illness threat_level  body_camera
# 188  Fontana    CA                    False       attack        False
# Andrew Earl Abernathy
#         id                   name      date manner_of_death armed   age  \
# 1008  1158  Andrew Earl Abernathy  08/01/16            shot   gun  50.0
#
#      gender race     city state  signs_of_mental_illness threat_level  \
# 1008      M    W  Acworth    GA                     True       attack
#
#       body_camera
# 1008        False
# Andrew Henson
#         id           name      date manner_of_death    armed   age gender  \
# 1410  1596  Andrew Henson  07/06/16            shot  unarmed  25.0      M
#
#      race     city state  signs_of_mental_illness threat_level  body_camera
# 1410    W  Wagoner    OK                    False        other         True
# Andrew Jackson
#       id            name      date manner_of_death  armed   age gender race  \
# 321  415  Andrew Jackson  29/04/15            shot  knife  26.0      M    W
#
#           city state  signs_of_mental_illness threat_level  body_camera
# 321  Chickasha    OK                    False        other        False
# Andrew Jospeh Todd
#        id                name      date manner_of_death armed   age gender  \
# 934  1082  Andrew Jospeh Todd  12/12/15            shot   gun  20.0      M
#
#     race              city state  signs_of_mental_illness threat_level  \
# 934    W  East Stroudsburg    PA                     True       attack
#
#      body_camera
# 934        False
# Andrew McClendon
#         id              name      date manner_of_death  armed   age gender  \
# 2101  2344  Andrew McClendon  15/02/17            shot  knife  33.0      M
#
#      race            city state  signs_of_mental_illness threat_level  \
# 2101    W  Cape Girardeau    MO                    False        other
#
#       body_camera
# 2101        False
# Andrew Mike
#         id         name      date manner_of_death armed   age gender race  \
# 1227  1406  Andrew Mike  24/03/16            shot   gun  29.0      M    W
#
#           city state  signs_of_mental_illness threat_level  body_camera
# 1227  Redlands    CA                    False       attack        False
# Andrew Moreno
#         id           name      date manner_of_death armed   age gender race  \
# 1848  2061  Andrew Moreno  20/11/16            shot   gun  24.0      M    H
#
#              city state  signs_of_mental_illness threat_level  body_camera
# 1848  San Antonio    TX                    False       attack        False
# Andrew Thomas
#        id           name      date manner_of_death    armed   age gender race  \
# 891  1104  Andrew Thomas  26/11/15            shot  unarmed  26.0      M    W
#
#       city state  signs_of_mental_illness threat_level  body_camera
# 891  Chico    CA                    False        other         True
# Andrew Toto
#     id         name      date manner_of_death armed   age gender race   city  \
# 49  98  Andrew Toto  21/01/15            shot   gun  54.0      M    W  Derry
#
#    state  signs_of_mental_illness threat_level  body_camera
# 49    NH                     True       attack        False
# Andrew Valadez
#       id            name      date manner_of_death armed   age gender race  \
# 304  392  Andrew Valadez  23/04/15            shot   gun  26.0      M    W
#
#        city state  signs_of_mental_illness threat_level  body_camera
# 304  Sylmar    CA                     True       attack        False
# Andy Martinez
#      id           name      date manner_of_death armed   age gender race  \
# 20  325  Andy Martinez  09/01/15            shot   gun  33.0      M    H
#
#        city state  signs_of_mental_illness threat_level  body_camera
# 20  El Paso    TX                    False       attack        False
# Angel Alan Gleason
#         id                name      date manner_of_death armed   age gender  \
# 1140  1309  Angel Alan Gleason  23/02/16            shot   gun  36.0      M
#
#      race   city state  signs_of_mental_illness threat_level  body_camera
# 1140    H  Ripon    CA                    False        other        False
# Angel Cresencio Corona
#       id                    name      date manner_of_death  armed   age  \
# 271  335  Angel Cresencio Corona  10/04/15            shot  knife  21.0
#
#     gender race     city state  signs_of_mental_illness threat_level  \
# 271      M    H  Corning    CA                    False       attack
#
#      body_camera
# 271        False
# Angel Daniel Navarro
#         id                  name      date manner_of_death armed   age gender  \
# 1386  1583  Angel Daniel Navarro  26/05/16            shot   gun  25.0      M
#
#      race     city state  signs_of_mental_illness threat_level  body_camera
# 1386    H  Socorro    NM                    False       attack        False
# Angel Montion
#         id           name      date manner_of_death armed   age gender race  \
# 1243  1423  Angel Montion  30/03/16            shot   gun  33.0      M    W
#
#              city state  signs_of_mental_illness threat_level  body_camera
# 1243  Los Angeles    CA                    False       attack        False
# Angel Ramos
#         id         name      date manner_of_death  armed   age gender race  \
# 2014  2235  Angel Ramos  23/01/17            shot  knife  21.0      M    H
#
#          city state  signs_of_mental_illness threat_level  body_camera
# 2014  Vallejo    CA                    False       attack         True
# Angel Torres Jr.
#         id              name      date manner_of_death       armed   age  \
# 1629  1820  Angel Torres Jr.  27/08/16            shot  toy weapon  26.0
#
#      gender race     city state  signs_of_mental_illness threat_level  \
# 1629      M    H  Phoenix    AZ                    False       attack
#
#       body_camera
# 1629        False
# Angela Hiatt
#         id          name      date manner_of_death    armed   age gender race  \
# 1062  1226  Angela Hiatt  29/01/16            shot  vehicle  41.0      F    W
#
#              city state  signs_of_mental_illness threat_level  body_camera
# 1062  Phenix City    AL                    False       attack        False
# Angelo Brown
#         id          name      date manner_of_death armed       age gender  \
# 1460  1649  Angelo Brown  23/06/16            shot   gun  36.60537      M
#
#      race        city state  signs_of_mental_illness threat_level  body_camera
# 1460    B  Belleville    IL                    False       attack        False
# Angelo Delano Perry
#       id                 name      date manner_of_death armed   age gender  \
# 675  807  Angelo Delano Perry  05/09/15            shot   gun  35.0      M
#
#     race            city state  signs_of_mental_illness threat_level  \
# 675    B  Virginia Beach    VA                    False       attack
#
#      body_camera
# 675        False
# Angelo West
#       id         name      date manner_of_death armed   age gender race  \
# 237  254  Angelo West  27/03/15            shot   gun  41.0      M    B
#
#        city state  signs_of_mental_illness threat_level  body_camera
# 237  Boston    MA                    False       attack        False
# Anthonie Smith
#       id            name      date   manner_of_death            armed   age  \
# 520  642  Anthonie Smith  16/07/15  shot and Tasered  metal hand tool  25.0
#
#     gender race           city state  signs_of_mental_illness threat_level  \
# 520      M    B  Moreno Valley    CA                     True        other
#
#      body_camera
# 520        False
# Anthony Aguilar
#       id             name      date   manner_of_death           armed   age  \
# 764  906  Anthony Aguilar  10/10/15  shot and Tasered  unknown weapon  35.0
#
#     gender race   city state  signs_of_mental_illness  threat_level  \
# 764      M    H  Lisle    IL                    False  undetermined
#
#      body_camera
# 764        False
# Anthony Ashford
#       id             name      date manner_of_death    armed   age gender  \
# 814  958  Anthony Ashford  28/10/15            shot  unarmed  29.0      M
#
#     race        city state  signs_of_mental_illness threat_level  body_camera
# 814    B  Point Loma    CA                    False       attack        False
# Anthony Bertoni
#         id             name      date manner_of_death armed   age gender race  \
# 1100  1260  Anthony Bertoni  10/02/16            shot   gun  56.0      M    O
#
#                   city state  signs_of_mental_illness threat_level  \
# 1100  Henderson County    TX                     True       attack
#
#       body_camera
# 1100        False
# Anthony Bess
#       id          name      date manner_of_death armed   age gender race  \
# 101  139  Anthony Bess  10/02/15            shot   gun  49.0      M    B
#
#            city state  signs_of_mental_illness threat_level  body_camera
# 101  Whitehaven    TN                    False       attack        False
# Anthony Briggs
#       id            name      date manner_of_death  armed   age gender race  \
# 380  476  Anthony Briggs  25/05/15            shot  knife  36.0      M    B
#
#            city state  signs_of_mental_illness threat_level  body_camera
# 380  Huntsville    AL                     True       attack        False
# Anthony David Soderberg
#         id                     name      date manner_of_death armed   age  \
# 2304  2568  Anthony David Soderberg  08/05/17            shot   gun  29.0
#
#      gender race         city state  signs_of_mental_illness threat_level  \
# 2304      M    W  Los Angeles    CA                    False       attack
#
#       body_camera
# 2304        False
# Anthony Giaquinta
#       id               name      date manner_of_death armed   age gender race  \
# 135  175  Anthony Giaquinta  23/02/15            shot   gun  41.0      M    W
#
#              city state  signs_of_mental_illness threat_level  body_camera
# 135  Clarkesville    GA                    False       attack        False
# Anthony Gomez
#       id           name      date manner_of_death armed   age gender race  \
# 365  466  Anthony Gomez  20/05/15            shot   gun  29.0      M    B
#
#           city state  signs_of_mental_illness threat_level  body_camera
# 365  Lancaster    PA                    False       attack        False
# Anthony Hill
#       id          name      date manner_of_death    armed   age gender race  \
# 174  205  Anthony Hill  09/03/15            shot  unarmed  27.0      M    B
#
#         city state  signs_of_mental_illness threat_level  body_camera
# 174  Atlanta    GA                     True        other        False
# Anthony Hodge
#       id           name      date manner_of_death armed   age gender race  \
# 431  546  Anthony Hodge  13/06/15            shot   gun  46.0      M    W
#
#            city state  signs_of_mental_illness threat_level  body_camera
# 431  Fort Wayne    IN                    False       attack        False
# Anthony Lorenzo Vallejo
#       id                     name      date manner_of_death armed   age  \
# 606  733  Anthony Lorenzo Vallejo  12/08/15            shot   gun  27.0
#
#     gender race   city state  signs_of_mental_illness threat_level  \
# 606      M    H  Hemet    CA                    False       attack
#
#      body_camera
# 606        False
# Anthony Lovell Eddington
#         id                      name      date manner_of_death armed   age  \
# 1929  2157  Anthony Lovell Eddington  21/12/16            shot   gun  24.0
#
#      gender race      city state  signs_of_mental_illness threat_level  \
# 1929      M    B  Coalinga    CA                    False       attack
#
#       body_camera
# 1929        False
# Anthony McKinney
#       id              name      date manner_of_death  armed   age gender race  \
# 735  869  Anthony McKinney  26/09/15            shot  knife  46.0      M    B
#
#             city state  signs_of_mental_illness threat_level  body_camera
# 735  Baton Rouge    LA                    False       attack        False
# Anthony Nunez
#         id           name      date manner_of_death armed   age gender race  \
# 1498  1681  Anthony Nunez  04/07/16            shot   gun  18.0      M    H
#
#           city state  signs_of_mental_illness threat_level  body_camera
# 1498  San Jose    CA                     True        other        False
# Anthony Paul Ardo
#         id               name      date manner_of_death      armed   age  \
# 2334  2592  Anthony Paul Ardo  20/05/17            shot  fireworks  47.0
#
#      gender race                city state  signs_of_mental_illness  \
# 2334      M    W  Lower Mount Bethel    PA                     True
#
#      threat_level  body_camera
# 2334        other        False
# Anthony Purvis
#      id            name      date manner_of_death armed   age gender race  \
# 82  120  Anthony Purvis  03/02/15            shot   gun  45.0      M    W
#
#        city state  signs_of_mental_illness threat_level  body_camera
# 82  Douglas    GA                     True       attack        False
# Anthony Ray Bauer
#         id               name      date manner_of_death armed   age gender  \
# 1706  1911  Anthony Ray Bauer  26/09/16            shot   gun  52.0      M
#
#      race         city state  signs_of_mental_illness threat_level  \
# 1706    W  Garden City    ID                    False       attack
#
#       body_camera
# 1706        False
# Antonio Arturo Perez Garcia
#         id                         name      date manner_of_death armed   age  \
# 2022  2255  Antonio Arturo Perez Garcia  24/01/17            shot   gun  27.0
#
#      gender race         city state  signs_of_mental_illness threat_level  \
# 2022      M    H  Bakersfield    CA                    False       attack
#
#       body_camera
# 2022        False
# Antonio Clements
#       id              name      date manner_of_death armed   age gender race  \
# 572  697  Antonio Clements  03/08/15            shot   gun  49.0      M    B
#
#         city state  signs_of_mental_illness threat_level  body_camera
# 572  Oakland    CA                    False       attack        False
# Antonio Garcia Jr.
#         id                name      date manner_of_death         armed   age  \
# 2484  2769  Antonio Garcia Jr.  11/07/17            shot  undetermined  47.0
#
#      gender race         city state  signs_of_mental_illness  threat_level  \
# 2484      M    B  Leavenworth    KS                    False  undetermined
#
#       body_camera
# 2484        False
# Antonio Gerardo Rodriguez
#         id                       name      date manner_of_death armed   age  \
# 2369  2634  Antonio Gerardo Rodriguez  02/06/17            shot   gun  55.0
#
#      gender race    city state  signs_of_mental_illness threat_level  \
# 2369      M    H  Laredo    TX                    False       attack
#
#       body_camera
# 2369        False
# Antonio Gonzalez
#       id              name      date manner_of_death  armed   age gender race  \
# 521  646  Antonio Gonzalez  16/07/15            shot  sword  29.0      M    H
#
#           city state  signs_of_mental_illness threat_level  body_camera
# 521  Wauwatosa    WI                     True        other        False
# Antonio Juarez
#         id            name      date manner_of_death armed   age gender race  \
# 2389  2652  Antonio Juarez  09/06/17            shot   gun  44.0      M    H
#
#        city state  signs_of_mental_illness threat_level  body_camera
# 2389  Lyons    IL                    False       attack        False
# Antonio Perez
#       id           name      date manner_of_death    armed   age gender race  \
# 189  351  Antonio Perez  13/03/15            shot  unarmed  32.0      M    H
#
#              city state  signs_of_mental_illness threat_level  body_camera
# 189  Walnut Creek    CA                    False        other        False
# Antonio Zambrano-Montes
#       id                     name      date   manner_of_death    armed   age  \
# 100  138  Antonio Zambrano-Montes  10/02/15  shot and Tasered  unarmed  35.0
#
#     gender race   city state  signs_of_mental_illness threat_level  \
# 100      M    H  Pasco    WA                     True        other
#
#      body_camera
# 100        False
# Antronie Scott
#         id            name      date manner_of_death    armed   age gender  \
# 1079  1237  Antronie Scott  04/02/16            shot  unarmed  36.0      M
#
#      race         city state  signs_of_mental_illness threat_level  \
# 1079    B  San Antonio    TX                    False        other
#
#       body_camera
# 1079        False
# Antwun Shumpert
#         id             name      date manner_of_death    armed   age gender  \
# 1445  1637  Antwun Shumpert  18/06/16            shot  unarmed  37.0      M
#
# ...
#
#      race     city state  signs_of_mental_illness threat_level  body_camera
# 1623    W  Orlando    FL                     True        other        False
# William Chau
#       id          name      date manner_of_death  armed   age gender race  \
# 685  879  William Chau  09/09/15            shot  knife  59.0      M    A
#
#          city state  signs_of_mental_illness threat_level  body_camera
# 685  El Monte    CA                    False       attack        False
# William Clark
#         id           name      date manner_of_death  armed   age gender race  \
# 1271  1451  William Clark  10/04/16            shot  knife  30.0      M    W
#
#            city state  signs_of_mental_illness threat_level  body_camera
# 1271  Rotterdam    NY                     True       attack        False
# William Clifford Cole
#         id                   name      date   manner_of_death    armed   age  \
# 1784  1996  William Clifford Cole  26/10/16  shot and Tasered  unarmed  36.0
#
#      gender race          city state  signs_of_mental_illness threat_level  \
# 1784      M    W  Bartlesville    OK                    False       attack
#
#       body_camera
# 1784        False
# William Combs
#       id           name      date manner_of_death    armed   age gender race  \
# 762  904  William Combs  10/10/15            shot  vehicle  38.0      M    W
#
#              city state  signs_of_mental_illness threat_level  body_camera
# 762  Pinion Hills    CA                     True        other        False
# William D. Fisher
#         id               name      date manner_of_death armed   age gender  \
# 2006  2242  William D. Fisher  19/01/17            shot   gun  49.0      M
#
#      race      city state  signs_of_mental_illness threat_level  body_camera
# 2006    W  Woodford    VA                     True        other        False
# William D. Spates
#         id               name      date manner_of_death    armed   age gender  \
# 2264  2522  William D. Spates  22/04/17            shot  vehicle  39.0      M
#
#      race     city state  signs_of_mental_illness threat_level  body_camera
# 2264    B  Portage    IN                     True        other        False
# William David Powell
#         id                  name      date manner_of_death armed   age gender  \
# 1413  1604  William David Powell  07/06/16            shot   gun  63.0      M
#
#      race         city state  signs_of_mental_illness threat_level  \
# 1413    W  Stockbridge    GA                    False       attack
#
#       body_camera
# 1413        False
# William David Raff
#        id                name      date manner_of_death  armed   age gender  \
# 977  1125  William David Raff  25/12/15            shot  knife  31.0      M
#
#     race       city state  signs_of_mental_illness threat_level  body_camera
# 977    W  Palo Alto    CA                     True       attack        False
# William David Whetstone
#         id                     name      date manner_of_death armed   age  \
# 2053  2289  William David Whetstone  03/02/17            shot   gun  33.0
#
#      gender race     city state  signs_of_mental_illness threat_level  \
# 2053      M    W  Hickory    NC                    False       attack
#
#       body_camera
# 2053         True
# William Dean
#         id          name      date manner_of_death armed   age gender race  \
# 2295  2555  William Dean  03/05/17            shot   gun  67.0      M    W
#
#                 city state  signs_of_mental_illness threat_level  body_camera
# 2295  Peachtree City    GA                     True       attack        False
# William Dean Poole
#       id                name      date manner_of_death armed   age gender  \
# 196  213  William Dean Poole  16/03/15            shot   gun  52.0      M
#
#     race      city state  signs_of_mental_illness threat_level  body_camera
# 196    W  Gastonia    NC                     True       attack        False
# William Dwayne Darby
#         id                  name      date manner_of_death armed   age gender  \
# 2136  2384  William Dwayne Darby  25/02/17            shot   gun  39.0      M
#
#      race     city state  signs_of_mental_illness threat_level  body_camera
# 2136    W  Lumpkin    GA                    False       attack        False
# William Evans
#       id           name      date manner_of_death armed   age gender race  \
# 654  786  William Evans  28/08/15            shot   gun  28.0      M    W
#
#              city state  signs_of_mental_illness threat_level  body_camera
# 654  Spanish Fork    UT                     True       attack         True
# William Frost
#         id           name      date   manner_of_death  armed   age gender  \
# 1772  1983  William Frost  21/10/16  shot and Tasered  knife  58.0      M
#
#      race   city state  signs_of_mental_illness threat_level  body_camera
# 1772    W  Tulsa    OK                    False        other        False
# William J. Beavers
#         id                name      date manner_of_death  armed   age gender  \
# 1856  2069  William J. Beavers  23/11/16            shot  knife  43.0      M
#
#      race     city state  signs_of_mental_illness threat_level  body_camera
# 1856    W  Lealman    FL                    False        other        False
# William Joseph Ryan
#         id                 name      date manner_of_death armed   age gender  \
# 1689  1896  William Joseph Ryan  17/09/16            shot   gun  55.0      M
#
#      race           city state  signs_of_mental_illness threat_level  \
# 1689    W  Rutherfordton    NC                     True       attack
#
#       body_camera
# 1689        False
# William Keith Waldron
#         id                   name      date manner_of_death armed   age  \
# 1021  1180  William Keith Waldron  15/01/16            shot   gun  26.0
#
#      gender race    city state  signs_of_mental_illness threat_level  \
# 1021      M    W  Elkins    WV                    False       attack
#
#       body_camera
# 1021        False
# William Lee Snider
#       id                name      date manner_of_death armed   age gender  \
# 640  767  William Lee Snider  23/08/15            shot   gun  57.0      M
#
#     race       city state  signs_of_mental_illness threat_level  body_camera
# 640    W  Las Vegas    NV                    False       attack        False
# William Lemmon
#       id            name      date manner_of_death    armed   age gender race  \
# 732  866  William Lemmon  25/09/15            shot  unarmed  21.0      M    W
#
#       city state  signs_of_mental_illness  threat_level  body_camera
# 732  Akron    OH                    False  undetermined        False
# William Michael Hollis
#         id                    name      date manner_of_death armed   age  \
# 1415  1603  William Michael Hollis  09/06/16            shot   gun  34.0
#
#      gender race        city state  signs_of_mental_illness threat_level  \
# 1415      M    W  Birmingham    AL                    False       attack
#
#       body_camera
# 1415        False
# William Rippley
#       id             name      date manner_of_death  armed   age gender race  \
# 662  792  William Rippley  31/08/15            shot  knife  45.0      M    W
#
#          city state  signs_of_mental_illness threat_level  body_camera
# 662  Loveland    CO                    False       attack        False
# William Russell  Smith
#       id                    name      date manner_of_death armed   age gender  \
# 184  581  William Russell  Smith  11/03/15            shot   gun  53.0      M
#
#     race    city state  signs_of_mental_illness threat_level  body_camera
# 184    W  Hoover    AL                     True       attack        False
# William Smith
#       id           name      date manner_of_death armed   age gender race  \
# 608  736  William Smith  12/08/15            shot   gun  49.0      M    W
#
#       city state  signs_of_mental_illness  threat_level  body_camera
# 608  Hobbs    NM                    False  undetermined        False
# William Spaits
#       id            name      date manner_of_death armed   age gender race  \
# 715  848  William Spaits  21/09/15            shot   gun  27.0      M    W
#
#           city state  signs_of_mental_illness threat_level  body_camera
# 715  Sand City    CA                    False       attack        False
# William Stokes
#         id            name      date manner_of_death    armed       age  \
# 2199  2449  William Stokes  23/03/17            shot  machete  36.60537
#
#      gender race        city state  signs_of_mental_illness threat_level  \
# 2199      M    B  Des Moines    WA                     True        other
#
#       body_camera
# 2199        False
# William Tarrant
#        id             name      date manner_of_death armed   age gender race  \
# 877  1024  William Tarrant  20/11/15            shot   gun  39.0      M    W
#
#                 city state  signs_of_mental_illness threat_level  body_camera
# 877  Paulding County    GA                     True       attack        False
# William Thomas Hennessey
#         id                      name      date manner_of_death       armed  \
# 1443  1633  William Thomas Hennessey  18/06/16            shot  toy weapon
#
#        age gender race        city state  signs_of_mental_illness  \
# 1443  34.0      M    W  Huntsville    AL                    False
#
#      threat_level  body_camera
# 1443       attack         True
# William Tracy Patterson
#         id                     name      date manner_of_death armed   age  \
# 1497  1679  William Tracy Patterson  04/07/16            shot   gun  34.0
#
#      gender race              city state  signs_of_mental_illness  \
# 1497      M    W  North Charleston    SC                    False
#
#      threat_level  body_camera
# 1497       attack         True
# William Tucker Mathis
#         id                   name      date manner_of_death    armed   age  \
# 1972  2199  William Tucker Mathis  07/01/17            shot  unarmed  41.0
#
#      gender race      city state  signs_of_mental_illness threat_level  \
# 1972      M    W  Elkridge    MD                     True       attack
#
#       body_camera
# 1972        False
# William Verrett
#       id             name      date manner_of_death armed   age gender race  \
# 679  811  William Verrett  06/09/15            shot   gun  45.0      M    W
#
#       city state  signs_of_mental_illness threat_level  body_camera
# 679  Hobbs    NM                    False       attack        False
# William Webster
#         id             name      date manner_of_death armed   age gender race  \
# 2415  2675  William Webster  18/06/17            shot   gun  64.0      M    W
#
#           city state  signs_of_mental_illness threat_level  body_camera
# 2415  Waukesha    WI                     True        other        False
# Willie Demetrius James
#         id                    name      date manner_of_death  armed   age  \
# 1400  1588  Willie Demetrius James  02/06/16            shot  knife  43.0
#
#      gender race     city state  signs_of_mental_illness threat_level  \
# 1400      M    B  Norfolk    VA                     True        other
#
#       body_camera
# 1400         True
# Willie Holderfield
#         id                name      date manner_of_death armed   age gender  \
# 1019  1168  Willie Holderfield  14/01/16            shot   gun  40.0      M
#
#      race   city state  signs_of_mental_illness threat_level  body_camera
# 1019    W  Hurst    IL                     True       attack        False
# Willie Tillman
#         id            name      date   manner_of_death    armed   age gender  \
# 1305  1527  Willie Tillman  23/04/16  shot and Tasered  vehicle  33.0      M
#
#      race          city state  signs_of_mental_illness threat_level  \
# 1305    B  Fayetteville    AR                    False        other
#
#       body_camera
# 1305         True
# Willis N. Walker
#         id              name      date manner_of_death armed   age gender  \
# 1412  1601  Willis N. Walker  07/06/16            shot   gun  49.0      M
#
#      race    city state  signs_of_mental_illness threat_level  body_camera
# 1412    B  Norman    VA                    False        other        False
# Wilton Henry
#         id          name      date manner_of_death armed   age gender race  \
# 1799  2009  Wilton Henry  02/11/16            shot   gun  59.0      M    W
#
#        city state  signs_of_mental_illness threat_level  body_camera
# 1799  Houma    LA                     True       attack         True
# Yia Lee
#         id     name      date manner_of_death armed   age gender race  \
# 2052  2285  Yia Lee  03/02/17            shot   gun  41.0      M    A
#
#            city state  signs_of_mental_illness threat_level  body_camera
# 2052  Panhandle    TX                    False       attack        False
# Yohans Leon
#        id         name      date manner_of_death armed   age gender race  \
# 867  1010  Yohans Leon  17/11/15            shot   gun  28.0      M    B
#
#       city state  signs_of_mental_illness threat_level  body_camera
# 867  Miami    FL                     True       attack        False
# Yonas Alehegne
#       id            name      date manner_of_death  armed   age gender race  \
# 650  782  Yonas Alehegne  27/08/15            shot  chain  30.0      M    B
#
#         city state  signs_of_mental_illness threat_level  body_camera
# 650  Oakland    CA                    False       attack         True
# Yuvette Henderson
#      id               name      date manner_of_death armed   age gender race  \
# 80  118  Yuvette Henderson  03/02/15            shot   gun  38.0      F    B
#
#           city state  signs_of_mental_illness threat_level  body_camera
# 80  Emeryville    CA                    False       attack        False
# Zachary Grigsby
#        id             name      date manner_of_death armed   age gender race  \
# 898  1042  Zachary Grigsby  29/11/15            shot   gun  29.0      M    W
#
#         city state  signs_of_mental_illness threat_level  body_camera
# 898  Lincoln    NE                    False       attack        False
# Zachary Hammond
#       id             name      date manner_of_death    armed   age gender  \
# 556  680  Zachary Hammond  26/07/15            shot  vehicle  19.0      M
#
#     race    city state  signs_of_mental_illness threat_level  body_camera
# 556    W  Seneca    SC                    False        other        False
# Zachary Sutton
#         id            name      date manner_of_death armed   age gender race  \
# 1728  1936  Zachary Sutton  04/10/16            shot   gun  26.0      M    W
#
#             city state  signs_of_mental_illness threat_level  body_camera
# 1728  Springdale    AR                    False       attack        False
# Zaki Shinwary
#     id           name      date   manner_of_death  armed   age gender race  \
# 38  68  Zaki Shinwary  16/01/15  shot and Tasered  knife  48.0      M    O
#
#        city state  signs_of_mental_illness threat_level  body_camera
# 38  Fremont    CA                    False        other        False
# Zane Terryn
#       id         name      date manner_of_death armed   age gender race  \
# 435  551  Zane Terryn  14/06/15            shot   gun  15.0      M    W
#
#       city state  signs_of_mental_illness threat_level  body_camera
# 435  Cocoa    FL                     True       attack        False
# Zelalem Eshetu Ewnetu
#         id                   name      date manner_of_death armed   age  \
# 2241  2496  Zelalem Eshetu Ewnetu  12/04/17            shot   gun  28.0
#
#      gender race         city state  signs_of_mental_illness threat_level  \
# 2241      M    B  Los Angeles    CA                    False        other
#
#       body_camera
# 2241        False
# Zhonghua Li
#         id         name      date manner_of_death     armed   age gender race  \
# 1937  2166  Zhonghua Li  24/12/16            shot  scissors  48.0      M    A
#
#              city state  signs_of_mental_illness threat_level  body_camera
# 1937  Pico Rivera    CA                     True       attack        False

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-2c5007e56b3f> in <module>()
#       1 new_kill = kill.replace('TK TK', 'UnKnown', inplace=True)
# ----> 2 new_kill.head(100)
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
poverty_level = pd.read_csv("/homes/alk30/DA_Project/Data/PercentagePeopleBelowPovertyLevel.csv",encoding='latin-1')
poverty_level_miss_values = poverty_level.isnull().sum()
poverty_level['poverty_rate'].replace(['-'],0.0,inplace = True)
poverty_level.poverty_rate.value_counts()
# Out:
# 0       1464
# 0.0      201
# 6.7      129
# 7.4      129
# 10.9     128
# 10       128
# 6.3      126
# 4.4      126
# 11.5     125
# 8.3      125
# 7.9      123
# 8.6      122
# 10.2     122
# 8.7      122
# 11.1     122
# 5.9      122
# 12.8     121
# 8.8      121
# 14.3     121
# 13.5     120
# 8.5      120
# 9.1      120
# 15.4     118
# 9.3      118
# 11.2     118
# 10.8     118
# 16       118
# 7.3      117
# 7.5      117
# 4.2      117
#         ...
# 64         1
# 87.3       1
# 69.3       1
# 92.9       1
# 72.4       1
# 71.1       1
# 77.8       1
# 85         1
# 70         1
# 65.1       1
# 50.7       1
# 77         1
# 76.7       1
# 86.6       1
# 73.2       1
# 67.6       1
# 88         1
# 74.6       1
# 62.2       1
# 44.5       1
# 74.3       1
# 92.7       1
# 76.5       1
# 58.5       1
# 58.6       1
# 68.6       1
# 98.6       1
# 56.5       1
# 78.3       1
# 70.7       1
# Name: poverty_rate, Length: 771, dtype: int64

# %%
#show the poverty rate of cities #
poverty_level.poverty_rate = poverty_level.poverty_rate.astype(float)
Area_list = list(poverty_level['Geographic Area'].unique())
poverty_ratio=[]
for i in Area_list:
    x=poverty_level[poverty_level['Geographic Area']== i]
    area_poverty_rate= sum(x.poverty_rate)/len(x)
    poverty_ratio.append(area_poverty_rate)
data_poverty_ratio = pd.DataFrame({'area_list': Area_list , 'poverty_rate':poverty_ratio})
poverty_ratio_index=(data_poverty_ratio['poverty_rate'].sort_values(ascending=False)).index.values
sorted_poverty_ratio = data_poverty_ratio.reindex(poverty_ratio_index)
plt.figure(figsize=(15,10))
sns.barplot(x=sorted_poverty_ra)

# %%
Median_house_income = pd.read_csv("/homes/alk30/DA_Project/Data/MedianHouseholdIncome2015.csv",encoding='latin-1')
#Median_house_income_miss_values = Median_house_income.isnull().sum()
Median_house_income.head(10)
# Out:
#   Geographic Area                 City Median Income
# 0              AL           Abanda CDP         11207
# 1              AL       Abbeville city         25615
# 2              AL      Adamsville city         42575
# 3              AL         Addison town         37083
# 4              AL           Akron town         21667
# 5              AL       Alabaster city         71816
# 6              AL     Albertville city         32911
# 7              AL  Alexander City city         29874
# 8              AL       Alexandria CDP         56058
# 9              AL      Aliceville city         21131

# %%
Race_by_city = pd.read_csv("/homes/alk30/DA_Project/Data/ShareRaceByCity.csv",encoding='latin-1')
Race_by_city_miss_values = Race_by_city.isnull().sum()
#Race_by_city_miss_values [ Race_by_city_miss_values >0 ]
Race_by_city.head(10)
# Out:
#   Geographic area                 City share_white share_black  \
# 0              AL           Abanda CDP        67.2        30.2
# 1              AL       Abbeville city        54.4        41.4
# 2              AL      Adamsville city        52.3        44.9
# 3              AL         Addison town        99.1         0.1
# 4              AL           Akron town        13.2        86.5
# 5              AL       Alabaster city        79.4        13.5
# 6              AL     Albertville city        75.9         1.9
# 7              AL  Alexander City city        62.2          32
# 8              AL       Alexandria CDP        87.4        10.2
# 9              AL      Aliceville city        22.6        74.9
#
#   share_native_american share_asian share_hispanic
# 0                     0           0            1.6
# 1                   0.1           1            3.1
# 2                   0.5         0.3            2.3
# 3                     0         0.1            0.4
# 4                     0           0            0.3
# 5                   0.4         0.9              9
# 6                   0.8         0.5           27.9
# 7                   0.2         0.9            4.8
# 8                   0.3         0.5            0.9
# 9                   0.1           0            1.2

# %%
percentage_complete_highschool = pd.read_csv("/homes/alk30/DA_Project/Data/PercentOver25CompletedHighSchool.csv",encoding='latin-1')
percentage_complete_highschool_miss_values = percentage_complete_highschool.isnull().sum()
percentage_complete_highschool['percent_completed_hs']=pd.to_numeric(percentage_complete_highschool['percent_completed_hs'],errors='coerce')
#percentage_complete_highschool_miss_values[percentage_complete_highschool_miss_values > 0]
#percentage_complete_highschool.head(10)
#percentage_complete_highschool.percent_completed_hs.mean()
percentage_complete_highschool.percent_completed_hs.replace('-',percentage_complete_highschool['percent_completed_hs'].mean(),inplace=True)
percentage_complete_highschool.percent_completed_hs.value_counts()
# Out:
# 100.0    1301
# 91.7      170
# 92.9      169
# 92.5      168
# 91.3      163
# 89.3      162
# 93.8      161
# 93.2      160
# 92.1      159
# 92.7      158
# 91.9      158
# 92.2      157
# 93.4      156
# 90.9      156
# 89.7      153
# 91.1      150
# 89.4      150
# 93.9      150
# 90.2      149
# 91.6      148
# 91.5      147
# 93.6      146
# 88.1      146
# 92.6      146
# 90.4      145
# 89.1      145
# 94.3      144
# 89.9      142
# 89.5      142
# 92.4      142
#          ...
# 28.3        1
# 29.2        1
# 30.5        1
# 34.0        1
# 20.8        1
# 27.0        1
# 56.2        1
# 47.9        1
# 34.1        1
# 25.9        1
# 32.6        1
# 37.3        1
# 16.1        1
# 33.1        1
# 37.1        1
# 25.5        1
# 7.9         1
# 17.2        1
# 33.5        1
# 24.1        1
# 21.8        1
# 8.3         1
# 36.8        1
# 41.0        1
# 51.5        1
# 26.6        1
# 21.2        1
# 27.5        1
# 22.4        1
# 15.3        1
# Name: percent_completed_hs, Length: 727, dtype: int64

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly as py
import plotly.graph_objs as go
init_notebook_mode(connected=True)

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

import cufflinks as cf
cf.go_offline()

from functools import reduce

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("/homes/alk30/DA_Project/Data"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-38-c05942a00dcd> in <module>()
#       2 import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#       3
# ----> 4 from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
#       5 import plotly as py
#       6 import plotly.graph_objs as go
#
# ModuleNotFoundError: No module named 'plotly'
